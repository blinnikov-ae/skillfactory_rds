# %%
# Загрузка библиотек

from IPython.display import display
from ipywidgets import IntProgress
from catboost import CatBoostRegressor
import numpy as np
import pandas as pd
import json
import ast
import re
from itertools import combinations
from statsmodels.stats import weightstats
from scipy import stats
from gensim.models import Word2Vec
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
import warnings

import sys
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from nltk.corpus import stopwords
from sklearn.metrics import mean_absolute_error, mean_squared_error, silhouette_score
from tqdm.notebook import tqdm
tqdm.pandas()

warnings.filterwarnings("ignore")

import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn.utils import shuffle
# Out:
# C:\Users\79262\anaconda3\lib\site-packages\tqdm\std.py:702: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
# Фиксация версий пакетов для воспроизводимости экспериментов
# !pip freeze > requirements.txt
# Out:
# WARNING: Could not generate requirement for distribution -umpy 1.18.5 (c:\users\79262\anaconda3\lib\site-packages): Parse error at "'-umpy==1'": Expected W:(abcd...)

# %%
# Фиксация random seed для воспроизводимости экспериментов
RS = 42

# %%
# Функция возвращает целевую метрику
def MAPE(y_true, y_pred):
    return np.mean(np.abs((y_pred-y_true)/y_true))

# %%
data = pd.read_csv('alt_data.csv')

# %%
data.sample(5)
# Out:
#         vendor  Руль  eqp_amount  eur_price   mileage  modelDate  \
# 149990       0     0           0    4012.00 152000.00    2005.00
# 52733        0     0          13    4312.00 335000.00    1996.00
# 101161       0     0          62       0.00 103000.00    2014.00
# 83983        0     0          46       0.00 176000.00    2010.00
# 118227       1     0           0    8915.00 200000.00    2007.00
#
#         numberOfDoors  parsing_unixtime  productionDate  eng_volume  ...  \
# 149990           4.00     1599647912.00         2006.00        1.90  ...
# 52733            4.00     1620203331.00         2001.00        2.20  ...
# 101161           5.00     1603217112.00         2018.00        3.00  ...
# 83983            4.00     1603238671.00         2010.00        2.00  ...
# 118227           4.00     1599647912.00         2008.00        2.40  ...
#
#         ПТС_Оригинал  ПТС_nan  Привод_задний  Привод_передний  Привод_полный  \
# 149990             1        0              0                1              0
# 52733              1        0              0                1              0
# 101161             1        0              0                0              1
# 83983              1        0              0                1              0
# 118227             1        0              0                1              0
#
#         gen_id_stat  own_time_stat  body_stat  bodyType_stat  color_stat
# 149990         1.00           0.85       0.60           0.55        0.74
# 52733          0.22           0.85       0.80           0.69        0.48
# 101161         1.00           0.72       1.20           1.21        0.83
# 83983          1.00           0.73       0.60           0.55        1.10
# 118227         1.00           0.85       0.60           0.38        0.83
#
# [5 rows x 59 columns]

# %%
data.isna().sum()
# Out:
# vendor                                  0
# Руль                                    0
# eqp_amount                              0
# eur_price                               0
# mileage                                 0
# modelDate                               0
# numberOfDoors                           0
# parsing_unixtime                        0
# productionDate                          0
# eng_volume                              0
# eng_pwr                                 0
# rel_model                               0
# eqp_rating                              0
# train                                   0
# sell_id                                 0
# premium_0                               0
# premium_1                               0
# desc_cluster_0                          0
# desc_cluster_1                          0
# desc_cluster_2                          0
# desc_cluster_3                          0
# desc_cluster_4                          0
# desc_cluster_5                          0
# brand_AUDI                              0
# brand_BMW                               0
# brand_HONDA                             0
# brand_INFINITI                          0
# brand_LEXUS                             0
# brand_MERCEDES                          0
# brand_MITSUBISHI                        0
# brand_NISSAN                            0
# brand_SKODA                             0
# brand_TOYOTA                            0
# brand_VOLKSWAGEN                        0
# brand_VOLVO                             0
# fuelType_бензин                         0
# fuelType_газ                            0
# fuelType_гибрид                         0
# fuelType_дизель                         0
# fuelType_электро                        0
# vehicleTransmission_автоматическая      0
# vehicleTransmission_вариатор            0
# vehicleTransmission_механическая        0
# vehicleTransmission_роботизированная    0
# Владельцы_1 владелец                    0
# Владельцы_2 владельца                   0
# Владельцы_3 или более                   0
# Владельцы_nan                           0
# ПТС_Дубликат                            0
# ПТС_Оригинал                            0
# ПТС_nan                                 0
# Привод_задний                           0
# Привод_передний                         0
# Привод_полный                           0
# gen_id_stat                             0
# own_time_stat                           0
# body_stat                               0
# bodyType_stat                           0
# color_stat                              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159043 entries, 0 to 159042
# Data columns (total 59 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   vendor                                159043 non-null  int64
#  1   Руль                                  159043 non-null  int64
#  2   eqp_amount                            159043 non-null  int64
#  3   eur_price                             159043 non-null  float64
#  4   mileage                               159043 non-null  float64
#  5   modelDate                             159043 non-null  float64
#  6   numberOfDoors                         159043 non-null  float64
#  7   parsing_unixtime                      159043 non-null  float64
#  8   productionDate                        159043 non-null  float64
#  9   eng_volume                            159043 non-null  float64
#  10  eng_pwr                               159043 non-null  float64
#  11  rel_model                             159043 non-null  float64
#  12  eqp_rating                            159043 non-null  float64
#  13  train                                 159043 non-null  int64
#  14  sell_id                               159043 non-null  float64
#  15  premium_0                             159043 non-null  int64
#  16  premium_1                             159043 non-null  int64
#  17  desc_cluster_0                        159043 non-null  int64
#  18  desc_cluster_1                        159043 non-null  int64
#  19  desc_cluster_2                        159043 non-null  int64
#  20  desc_cluster_3                        159043 non-null  int64
#  21  desc_cluster_4                        159043 non-null  int64
#  22  desc_cluster_5                        159043 non-null  int64
#  23  brand_AUDI                            159043 non-null  int64
#  24  brand_BMW                             159043 non-null  int64
#  25  brand_HONDA                           159043 non-null  int64
#  26  brand_INFINITI                        159043 non-null  int64
#  27  brand_LEXUS                           159043 non-null  int64
#  28  brand_MERCEDES                        159043 non-null  int64
#  29  brand_MITSUBISHI                      159043 non-null  int64
#  30  brand_NISSAN                          159043 non-null  int64
#  31  brand_SKODA                           159043 non-null  int64
#  32  brand_TOYOTA                          159043 non-null  int64
#  33  brand_VOLKSWAGEN                      159043 non-null  int64
#  34  brand_VOLVO                           159043 non-null  int64
#  35  fuelType_бензин                       159043 non-null  int64
#  36  fuelType_газ                          159043 non-null  int64
#  37  fuelType_гибрид                       159043 non-null  int64
#  38  fuelType_дизель                       159043 non-null  int64
#  39  fuelType_электро                      159043 non-null  int64
#  40  vehicleTransmission_автоматическая    159043 non-null  int64
#  41  vehicleTransmission_вариатор          159043 non-null  int64
#  42  vehicleTransmission_механическая      159043 non-null  int64
#  43  vehicleTransmission_роботизированная  159043 non-null  int64
#  44  Владельцы_1 владелец                  159043 non-null  int64
#  45  Владельцы_2 владельца                 159043 non-null  int64
#  46  Владельцы_3 или более                 159043 non-null  int64
#  47  Владельцы_nan                         159043 non-null  int64
#  48  ПТС_Дубликат                          159043 non-null  int64
#  49  ПТС_Оригинал                          159043 non-null  int64
#  50  ПТС_nan                               159043 non-null  int64
#  51  Привод_задний                         159043 non-null  int64
#  52  Привод_передний                       159043 non-null  int64
#  53  Привод_полный                         159043 non-null  int64
#  54  gen_id_stat                           159043 non-null  float64
#  55  own_time_stat                         159043 non-null  float64
#  56  body_stat                             159043 non-null  float64
#  57  bodyType_stat                         159043 non-null  float64
#  58  color_stat                            159043 non-null  float64
# dtypes: float64(16), int64(43)
# memory usage: 71.6 MB

# %% [markdown]
# Пропусков в данных нет. Тип всех данных: int или float

# %% [markdown]
# В качестве базовой модели мы использовали CatBoost и получили MAPE = 0.13379

# %% [markdown]
# ## Дополнительные модели
#
# Для улучшения результата, блэндинга и стэкинга будут использованы следующие модели:
# - Две базовые модели для противоположных эстремальных подходов:
# > - Глубокое дерево для максимального заучивания данных
# > - Линейная регрессия для отображения общего тренда
#
# - Альтернативные ансамбли:
# > - Стандартный бэггинг RandomForest
# > - Базовый градиентный бустинг от sklearn

# %%
# Функция возвращает метрики для данных и модели (MAPE с кросс-валидацией и без нее)
def alt_metics(data, target, model=CatBoostRegressor(random_seed=RS, silent=True)):
    df = data[data.train == 1].drop(['train', 'sell_id'], axis=1).copy()

    # Разделение переменных
    X = df.drop(target, axis=1).values
    y = df[target].values

    # Создание списков для записи локальных результатов
    local_mape = []

    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.fit(X_train, np.log(y_train))
        preds = np.exp(model.predict(X_test))
        local_mape.append(MAPE(y_test, preds))

    # Усреднение метрики
    result = []
    result.append(np.mean(local_mape))

    # Добавление мерики без кросс-валидации
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, shuffle=True, random_state=RS)
    model.fit(X_train, np.log(y_train))
    preds = np.exp(model.predict(X_test))
    result.append(MAPE(y_test, preds))

    return result

# %% [markdown]
# ### Lazy Predict

# %%
# Посмотрим, какие еще модели могут представлять интерес
# Обучим LazyRegressor на небольших выборках из датасета

scaler = StandardScaler()

small_data = data[data.train==1].sample(20000).drop(['train','sell_id'], axis=1).copy()

X = small_data.drop('eur_price', axis=1).values
X = scaler.fit_transform(X) 
y = small_data['eur_price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=RS)

regr=LazyRegressor(verbose=0,predictions=True)

models_r,predictions_r=regr.fit(X_train, X_test, np.log(y_train), np.log(y_test))

models_r
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [03:56<00:00,  5.63s/it]
#                                Adjusted R-Squared     R-Squared     RMSE  \
# Model
# LGBMRegressor                                0.95          0.95     0.23
# HistGradientBoostingRegressor                0.95          0.95     0.23
# RandomForestRegressor                        0.95          0.95     0.23
# ExtraTreesRegressor                          0.95          0.95     0.23
# XGBRegressor                                 0.95          0.95     0.23
# NuSVR                                        0.95          0.95     0.23
# SVR                                          0.95          0.95     0.23
# BaggingRegressor                             0.95          0.95     0.24
# GradientBoostingRegressor                    0.94          0.94     0.25
# MLPRegressor                                 0.94          0.94     0.26
# DecisionTreeRegressor                        0.91          0.91     0.31
# Ridge                                        0.91          0.91     0.31
# TransformedTargetRegressor                   0.91          0.91     0.31
# LinearRegression                             0.91          0.91     0.31
# RidgeCV                                      0.91          0.91     0.31
# BayesianRidge                                0.91          0.91     0.31
# ElasticNetCV                                 0.91          0.91     0.31
# LassoCV                                      0.91          0.91     0.31
# PoissonRegressor                             0.91          0.91     0.32
# HuberRegressor                               0.91          0.91     0.32
# LinearSVR                                    0.90          0.91     0.33
# LassoLarsCV                                  0.90          0.90     0.33
# LarsCV                                       0.90          0.90     0.33
# LassoLarsIC                                  0.90          0.90     0.33
# RANSACRegressor                              0.90          0.90     0.33
# ExtraTreeRegressor                           0.90          0.90     0.34
# Lars                                         0.89          0.90     0.34
# AdaBoostRegressor                            0.89          0.89     0.34
# KNeighborsRegressor                          0.88          0.88     0.37
# GeneralizedLinearRegressor                   0.87          0.88     0.37
# TweedieRegressor                             0.87          0.88     0.37
# GammaRegressor                               0.87          0.88     0.37
# OrthogonalMatchingPursuit                    0.86          0.86     0.40
# OrthogonalMatchingPursuitCV                  0.86          0.86     0.40
# PassiveAggressiveRegressor                   0.83          0.84     0.43
# ElasticNet                                   0.39          0.40     0.82
# Lasso                                       -0.01         -0.00     1.06
# DummyRegressor                              -0.01         -0.00     1.06
# LassoLars                                   -0.01         -0.00     1.06
# GaussianProcessRegressor                   -45.53        -44.88     7.18
# KernelRidge                                -73.59        -72.55     9.09
# SGDRegressor                        -428469066.74 -422468999.77 21775.24
#
#                                Time Taken
# Model
# LGBMRegressor                        0.52
# HistGradientBoostingRegressor        3.81
# RandomForestRegressor               11.91
# ExtraTreesRegressor                 10.27
# XGBRegressor                         2.47
# NuSVR                               39.99
# SVR                                 16.27
# BaggingRegressor                     1.27
# GradientBoostingRegressor            4.33
# MLPRegressor                        18.34
# DecisionTreeRegressor                0.23
# Ridge                                0.06
# TransformedTargetRegressor           0.11
# LinearRegression                     0.10
# RidgeCV                              0.12
# BayesianRidge                        0.10
# ElasticNetCV                         2.46
# LassoCV                              1.41
# PoissonRegressor                     0.09
# HuberRegressor                       0.56
# LinearSVR                            3.41
# LassoLarsCV                          0.27
# LarsCV                               0.33
# LassoLarsIC                          0.09
# RANSACRegressor                      0.45
# ExtraTreeRegressor                   0.15
# Lars                                 0.08
# AdaBoostRegressor                    2.20
# KNeighborsRegressor                  5.14
# GeneralizedLinearRegressor           0.07
# TweedieRegressor                     0.06
# GammaRegressor                       0.07
# OrthogonalMatchingPursuit            0.06
# OrthogonalMatchingPursuitCV          0.17
# PassiveAggressiveRegressor           0.07
# ElasticNet                           0.11
# Lasso                                0.11
# DummyRegressor                       0.05
# LassoLars                            0.07
# GaussianProcessRegressor            75.60
# KernelRidge                         33.53
# SGDRegressor                         0.07

# %%
small_data = data[data.train==1].sample(20000).drop(['train','sell_id'], axis=1).copy()

X = small_data.drop('eur_price', axis=1).values
X = scaler.fit_transform(X) 
y = small_data['eur_price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=RS)

regr=LazyRegressor(verbose=0,predictions=True)

models_r,predictions_r=regr.fit(X_train, X_test, np.log(y_train), np.log(y_test))

models_r
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [04:06<00:00,  5.86s/it]
#                                Adjusted R-Squared   R-Squared    RMSE  \
# Model
# XGBRegressor                                 0.96        0.96    0.23
# LGBMRegressor                                0.96        0.96    0.23
# HistGradientBoostingRegressor                0.95        0.96    0.23
# ExtraTreesRegressor                          0.95        0.95    0.23
# RandomForestRegressor                        0.95        0.95    0.23
# NuSVR                                        0.95        0.95    0.24
# SVR                                          0.95        0.95    0.24
# BaggingRegressor                             0.95        0.95    0.24
# GradientBoostingRegressor                    0.95        0.95    0.25
# MLPRegressor                                 0.94        0.94    0.26
# DecisionTreeRegressor                        0.92        0.92    0.30
# ElasticNetCV                                 0.91        0.91    0.33
# LassoCV                                      0.91        0.91    0.33
# BayesianRidge                                0.91        0.91    0.33
# RidgeCV                                      0.91        0.91    0.33
# Ridge                                        0.91        0.91    0.33
# TransformedTargetRegressor                   0.91        0.91    0.33
# LinearRegression                             0.91        0.91    0.33
# PoissonRegressor                             0.91        0.91    0.33
# LassoLarsCV                                  0.90        0.90    0.34
# LassoLarsIC                                  0.90        0.90    0.34
# LarsCV                                       0.90        0.90    0.34
# HuberRegressor                               0.90        0.90    0.34
# AdaBoostRegressor                            0.90        0.90    0.34
# RANSACRegressor                              0.90        0.90    0.34
# LinearSVR                                    0.90        0.90    0.35
# ExtraTreeRegressor                           0.89        0.89    0.35
# KNeighborsRegressor                          0.89        0.89    0.36
# GammaRegressor                               0.87        0.87    0.38
# GeneralizedLinearRegressor                   0.87        0.87    0.38
# TweedieRegressor                             0.87        0.87    0.38
# OrthogonalMatchingPursuit                    0.84        0.84    0.43
# OrthogonalMatchingPursuitCV                  0.84        0.84    0.43
# PassiveAggressiveRegressor                   0.81        0.81    0.47
# Lars                                         0.58        0.59    0.69
# ElasticNet                                   0.39        0.40    0.84
# DummyRegressor                              -0.01       -0.00    1.08
# Lasso                                       -0.01       -0.00    1.08
# LassoLars                                   -0.01       -0.00    1.08
# GaussianProcessRegressor                   -32.19      -31.73    6.15
# KernelRidge                                -71.78      -70.76    9.11
# SGDRegressor                          -5743075.21 -5662652.03 2558.11
#
#                                Time Taken
# Model
# XGBRegressor                         2.13
# LGBMRegressor                        0.58
# HistGradientBoostingRegressor        3.98
# ExtraTreesRegressor                 12.45
# RandomForestRegressor               12.39
# NuSVR                               42.26
# SVR                                 18.13
# BaggingRegressor                     1.38
# GradientBoostingRegressor            3.91
# MLPRegressor                        23.90
# DecisionTreeRegressor                0.23
# ElasticNetCV                         6.08
# LassoCV                              3.25
# BayesianRidge                        0.10
# RidgeCV                              0.13
# Ridge                                0.06
# TransformedTargetRegressor           0.09
# LinearRegression                     0.08
# PoissonRegressor                     0.10
# LassoLarsCV                          0.25
# LassoLarsIC                          0.08
# LarsCV                               0.31
# HuberRegressor                       0.65
# AdaBoostRegressor                    2.22
# RANSACRegressor                      0.55
# LinearSVR                            3.25
# ExtraTreeRegressor                   0.17
# KNeighborsRegressor                  5.61
# GammaRegressor                       0.07
# GeneralizedLinearRegressor           0.09
# TweedieRegressor                     0.06
# OrthogonalMatchingPursuit            0.08
# OrthogonalMatchingPursuitCV          0.17
# PassiveAggressiveRegressor           0.14
# Lars                                 0.08
# ElasticNet                           0.09
# DummyRegressor                       0.07
# Lasso                                0.08
# LassoLars                            0.07
# GaussianProcessRegressor            68.79
# KernelRidge                         31.92
# SGDRegressor                         0.06

# %% [markdown]
# Как видно, хорошо бы еще проверить XGBRegressor и ExtraTreesRegressor

# %% [markdown]
# ### DecisionTree

# %%
# Дефолтные параметры
DT = DecisionTreeRegressor(random_state=RS)
alt_results = pd.DataFrame({'DT': alt_metics(data, 'eur_price', model=DT)},
                           index=['CV', 'TST0.3'])
alt_results
# Out:
#          DT
# CV     0.20
# TST0.3 0.20

# %%
df = data[data.train == 1].drop(['train', 'sell_id'], axis=1).copy()

X = df.drop('eur_price', axis=1).values
y = df['eur_price'].values

# %%
# Подбор параметров

'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

DF = DecisionTreeRegressor(random_state=RS)

splitter = ['best', 'random']
max_features = ['auto', 'sqrt', 'log2', None]
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

random_grid = {'splitter': splitter,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               }

DF_random = RandomizedSearchCV(estimator = DF, param_distributions = random_grid, 
                               n_iter = 100, cv = 3, verbose=2, random_state=RS, n_jobs=-1)
DF_random.fit(X_train, np.log(y_train))

DF_random.best_params_'''
# Out:
# "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)\n\nDF = DecisionTreeRegressor(random_state=RS)\n\nsplitter = ['best', 'random']\nmax_features = ['auto', 'sqrt', 'log2', None]\nmax_depth = [int(x) for x in np.linspace(10, 110, num = 11)]\nmax_depth.append(None)\nmin_samples_split = [2, 5, 10]\nmin_samples_leaf = [1, 2, 4]\n\nrandom_grid = {'splitter': splitter,\n               'max_features': max_features,\n               'max_depth': max_depth,\n               'min_samples_split': min_samples_split,\n               'min_samples_leaf': min_samples_leaf,\n               }\n\nDF_random = RandomizedSearchCV(estimator = DF, param_distributions = random_grid, \n                               n_iter = 100, cv = 3, verbose=2, random_state=RS, n_jobs=-1)\nDF_random.fit(X_train, np.log(y_train))\n\nDF_random.best_params_"

# %% [markdown]
# Лучшие параметры: {'splitter': 'random',
#                      'min_samples_split': 10,
#                      'min_samples_leaf': 4,
#                      'max_features': 'auto',
#                      'max_depth': 90}

# %%
# Обучим модель с подобранными параметрами
DT = DecisionTreeRegressor(splitter='random', 
                           min_samples_split=10, 
                           min_samples_leaf=4, 
                           max_features='auto', 
                           max_depth=90, 
                           random_state=RS)
alt_results['DT_new'] = alt_metics(data, 'eur_price', model=DT)
alt_results
# Out:
#          DT  DT_new
# CV     0.20    0.17
# TST0.3 0.20    0.17

# %% [markdown]
# Метрика улучшилась, но хуже базовой модели

# %% [markdown]
# ### Linear regression

# %%
# Модель на ненормализованных данных
LR = LinearRegression(n_jobs=-1)
alt_results['LR'] = alt_metics(data, 'eur_price', model=LR)

alt_results
# Out:
#          DT  DT_new   LR
# CV     0.20    0.17 0.24
# TST0.3 0.20    0.17 0.23

# %%
# Функция возвращает метрики для нормализованных данных и модели (MAPE с кросс-валидацией и без нее)
def norm_alt_metics(data, target, scaler, model=CatBoostRegressor(random_seed=RS, silent=True)):
    df = data[data.train == 1].drop(['train', 'sell_id'], axis=1).copy()

    # Разделение переменных
    X = df.drop(target, axis=1).values
    X = scaler.fit_transform(X)
    y = df[target].values

    # Создание списков для записи локальных результатов
    local_mape = []

    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.fit(X_train, np.log(y_train))
        preds = np.exp(model.predict(X_test))
        local_mape.append(MAPE(y_test, preds))

    # Усреднение метрики
    result = []
    result.append(np.mean(local_mape))

    # Добавление метрики без кросс-валидации
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, shuffle=True, random_state=RS)
    model.fit(X_train, np.log(y_train))
    preds = np.exp(model.predict(X_test))
    result.append(MAPE(y_test, preds))

    return result

# %%
# Построим линейную регрессию, построенную на признаках, нормализованных с помощью StandardScaler
LR = LinearRegression(n_jobs=-1)

alt_results['LR(ss)'] = norm_alt_metics(data, 'eur_price', scaler=RobustScaler(), model=LR)

alt_results
# Out:
#          DT  DT_new   LR  LR(ss)
# CV     0.20    0.17 0.24    0.24
# TST0.3 0.20    0.17 0.23    0.23

# %%
# Построим линейную регрессию, построенную на признаках, нормализованных с помощью RobustScaler
from sklearn.preprocessing import RobustScaler

LR = LinearRegression(n_jobs=-1)

alt_results['LR(rs)'] = norm_alt_metics(data, 'eur_price', scaler=RobustScaler(), model=LR)

alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)
# CV     0.20    0.17 0.24    0.24    0.24
# TST0.3 0.20    0.17 0.23    0.23    0.23

# %% [markdown]
# Линейная регрессия работает плохо, что было ожидаемо

# %% [markdown]
# ### Random Forest

# %%
# Параметры по умолчанию
RF = RandomForestRegressor(random_state=RS)

alt_results['RF'] = alt_metics(data, 'eur_price', model=RF)
alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)   RF
# CV     0.20    0.17 0.24    0.24    0.24 0.14
# TST0.3 0.20    0.17 0.23    0.23    0.23 0.14

# %%
# Подбор параметров
'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

RF = RandomForestRegressor(random_state=RS)

n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

RF_random = RandomizedSearchCV(estimator = RF, param_distributions = random_grid, 
                               n_iter = 100, cv = 3, verbose=2, random_state=RS, n_jobs = -1)
RF_random.fit(X_train, y_train)
# Посмотрим, какие гиперпараметры нам предлагают как оптимальные:
RF_random.best_params_'''
# Out:
# "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)\n\nRF = RandomForestRegressor(random_state=RS)\n\nn_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]\nmax_features = ['auto', 'sqrt']\nmax_depth = [int(x) for x in np.linspace(10, 110, num = 11)]\nmax_depth.append(None)\nmin_samples_split = [2, 5, 10]\nmin_samples_leaf = [1, 2, 4]\nbootstrap = [True, False]\n\nrandom_grid = {'n_estimators': n_estimators,\n               'max_features': max_features,\n               'max_depth': max_depth,\n               'min_samples_split': min_samples_split,\n               'min_samples_leaf': min_samples_leaf,\n               'bootstrap': bootstrap}\n\nRF_random = RandomizedSearchCV(estimator = RF, param_distributions = random_grid, \n                               n_iter = 100, cv = 3, verbose=2, random_state=RS, n_jobs = -1)\nRF_random.fit(X_train, y_train)\n# Посмотрим, какие гиперпараметры нам предлагают как оптимальные:\nRF_random.best_params_"

# %% [markdown]
# Получили следующие значения: 'n_estimators': 1400, 'min_samples_split': 5, 'min_samples_leaf': 1,
# 'max_features': 'sqrt', 'max_depth': 80, 'bootstrap': False

# %%
# Обучим RF модель на подобранных параметрах
RF = RandomForestRegressor(n_estimators=1400, min_samples_split=5, min_samples_leaf=1, 
                           max_features='sqrt', max_depth=80, bootstrap=False, random_state=RS)

alt_results['RF_new'] = alt_metics(data, 'eur_price', model=RF)
alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)   RF  RF_new
# CV     0.20    0.17 0.24    0.24    0.24 0.14    0.14
# TST0.3 0.20    0.17 0.23    0.23    0.23 0.14    0.14

# %% [markdown]
# ### Gradient Boosting

# %%
# Параметры по умолчанию
GB = GradientBoostingRegressor(random_state=RS)
alt_results['GB'] =alt_metics(data, 'eur_price', model=GB)
alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)   RF  RF_new   GB
# CV     0.20    0.17 0.24    0.24    0.24 0.14    0.14 0.18
# TST0.3 0.20    0.17 0.23    0.23    0.23 0.14    0.14 0.18

# %%
# Подбор параметров
'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

GB = GradientBoostingRegressor(random_state=RS)

param_grid = {'learning_rate':[0.00001, 0.0001, 0.001, 0.01, 0.1, 1], 
              'n_estimators':[100, 250, 500, 750, 1000]}
gridsearch = GridSearchCV(GB, param_grid, n_jobs=-1, cv=3)
gridsearch.fit(X_train, y_train)
model = gridsearch.best_estimator_

# печатаем параметры
best_parameters = model.get_params()
for param_name in best_parameters:
    print(param_name, best_parameters[param_name], '\n')'''
# Out:
# "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)\n\nGB = GradientBoostingRegressor(random_state=RS)\n\nparam_grid = {'learning_rate':[0.00001, 0.0001, 0.001, 0.01, 0.1, 1], \n              'n_estimators':[100, 250, 500, 750, 1000]}\ngridsearch = GridSearchCV(GB, param_grid, n_jobs=-1, cv=3)\ngridsearch.fit(X_train, y_train)\nmodel = gridsearch.best_estimator_\n\n# печатаем параметры\nbest_parameters = model.get_params()\nfor param_name in best_parameters:\n    print(param_name, best_parameters[param_name], '\n')"

# %% [markdown]
# Получили параметры:
#
# learning_rate 0.1
#
# n_estimators 750

# %%
# Обучим модель с новыми параметрами
GB = GradientBoostingRegressor(learning_rate=0.1, n_estimators=750, random_state=RS)
alt_results['GB_new'] = alt_metics(data, 'eur_price', model=GB)
alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)   RF  RF_new   GB  GB_new
# CV     0.20    0.17 0.24    0.24    0.24 0.14    0.14 0.18    0.15
# TST0.3 0.20    0.17 0.23    0.23    0.23 0.14    0.14 0.18    0.15

# %% [markdown]
# ### ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
# Параметры по умолчанию
ETR = ExtraTreesRegressor(random_state=RS)

alt_results['ETR'] = alt_metics(data, 'eur_price', model=ETR)
alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)   RF  RF_new   GB  GB_new  ETR
# CV     0.20    0.17 0.24    0.24    0.24 0.14    0.14 0.18    0.15 0.14
# TST0.3 0.20    0.17 0.23    0.23    0.23 0.14    0.14 0.18    0.15 0.14

# %%
# Подбор параметров
'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

ETR = ExtraTreesRegressor(random_state=RS)

param_grid = {'learning_rate':[0.0001, 0.001, 0.01, 0.1, 1], 
              'n_estimators':[100, 250, 500, 750, 1000],
              'max_depth': [10, 25, 40, 55, 70, 85, 100, None], 
              'min_samples_split': [2, 5, 10], 
              'min_samples_leaf': [1, 2, 4], 
              'max_features': ['auto', 'sqrt']}
gridsearch = GridSearchCV(GB, param_grid, n_jobs=-1, cv=3)
gridsearch.fit(X_train, y_train)
model = gridsearch.best_estimator_

# печатаем параметры
best_parameters = model.get_params()
for param_name in best_parameters:
    print(param_name, best_parameters[param_name], '\n')'''
# Не хватило вычислительной мощности
# Out:
# "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)\n\nETR = ExtraTreesRegressor(random_state=RS)\n\nparam_grid = {'learning_rate':[0.0001, 0.001, 0.01, 0.1, 1], \n              'n_estimators':[100, 250, 500, 750, 1000],\n              'max_depth': [10, 25, 40, 55, 70, 85, 100, None], \n              'min_samples_split': [2, 5, 10], \n              'min_samples_leaf': [1, 2, 4], \n              'max_features': ['auto', 'sqrt']}\ngridsearch = GridSearchCV(GB, param_grid, n_jobs=-1, cv=3)\ngridsearch.fit(X_train, y_train)\nmodel = gridsearch.best_estimator_\n\n# печатаем параметры\nbest_parameters = model.get_params()\nfor param_name in best_parameters:\n    print(param_name, best_parameters[param_name], '\n')"

# %% [markdown]
# ### HistGradientBoosting

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
# Параметры по умолчанию
HGB = HistGradientBoostingRegressor(random_state=RS)

alt_results['HGB'] = alt_metics(data, 'eur_price', model=HGB)
alt_results
# Out:
#          DT  DT_new   LR  LR(ss)  LR(rs)   RF  RF_new   GB  GB_new  ETR  HGB
# CV     0.20    0.17 0.24    0.24    0.24 0.14    0.14 0.18    0.15 0.14 0.15
# TST0.3 0.20    0.17 0.23    0.23    0.23 0.14    0.14 0.18    0.15 0.14 0.15
